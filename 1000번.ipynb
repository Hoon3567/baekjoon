# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoon3567/baekjoon/blob/main/1000%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b = input().split()
print(int(a)+int(b))
# Out:
# 1 2
# 3
